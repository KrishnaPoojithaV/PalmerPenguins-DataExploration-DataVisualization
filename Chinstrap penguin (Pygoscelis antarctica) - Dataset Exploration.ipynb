# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df3 = pd.read_csv("table_221.csv")
df3.head()
# Out:
#   studyName  Sample Number                                    Species  Region  \
# 0   PAL0708              1  Chinstrap penguin (Pygoscelis antarctica)  Anvers
# 1   PAL0708              2  Chinstrap penguin (Pygoscelis antarctica)  Anvers
# 2   PAL0708              3  Chinstrap penguin (Pygoscelis antarctica)  Anvers
# 3   PAL0708              4  Chinstrap penguin (Pygoscelis antarctica)  Anvers
# 4   PAL0708              5  Chinstrap penguin (Pygoscelis antarctica)  Anvers
#
#   Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Dream  Adult, 1 Egg Stage         N61A1                No  2007-11-19
# 1  Dream  Adult, 1 Egg Stage         N61A2                No  2007-11-19
# 2  Dream  Adult, 1 Egg Stage         N62A1               Yes  2007-11-26
# 3  Dream  Adult, 1 Egg Stage         N62A2               Yes  2007-11-26
# 4  Dream  Adult, 1 Egg Stage         N64A1               Yes  2007-11-21
#
# ...

# %%
df3.describe()
# Out:
#        Sample Number  Culmen Length (mm)  Culmen Depth (mm)  \
# count       68.00000           68.000000          68.000000
# mean        34.50000           48.833824          18.420588
# std         19.77372            3.339256           1.135395
# min          1.00000           40.900000          16.400000
# 25%         17.75000           46.350000          17.500000
# 50%         34.50000           49.550000          18.450000
# 75%         51.25000           51.075000          19.400000
# max         68.00000           58.000000          20.800000
#
#        Flipper Length (mm)  Body Mass (g)  Delta 15 N (o/oo)  \
# count            68.000000      68.000000          67.000000
# mean            195.823529    3733.088235           9.356155
# std               7.131894     384.335081           0.368720
# min             178.000000    2700.000000           8.471730
# 25%             191.000000    3487.500000           9.103675
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            68 non-null     object
#  1   Sample Number        68 non-null     int64
#  2   Species              68 non-null     object
#  3   Region               68 non-null     object
#  4   Island               68 non-null     object
#  5   Stage                68 non-null     object
#  6   Individual ID        68 non-null     object
#  7   Clutch Completion    68 non-null     object
#  8   Date Egg             68 non-null     object
#  9   Culmen Length (mm)   68 non-null     float64
#  10  Culmen Depth (mm)    68 non-null     float64
#  11  Flipper Length (mm)  68 non-null     int64
#  12  Body Mass (g)        68 non-null     int64
#  13  Sex                  68 non-null     object
#  14  Delta 15 N (o/oo)    67 non-null     float64
# ...

# %%
df3.isnull().sum()
# Out:
# studyName               0
# Sample Number           0
# Species                 0
# Region                  0
# Island                  0
# Stage                   0
# Individual ID           0
# Clutch Completion       0
# Date Egg                0
# Culmen Length (mm)      0
# Culmen Depth (mm)       0
# Flipper Length (mm)     0
# Body Mass (g)           0
# Sex                     0
# Delta 15 N (o/oo)       1
# Delta 13 C (o/oo)       0
# Comments               53
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
sns.heatmap(df3.isnull(),cmap='viridis')

# %%
sns.pairplot(df3)

# %%
plt.hist(df3['Culmen Length (mm)'],bins=30)
# Out:
# (array([1., 0., 3., 0., 2., 0., 0., 3., 6., 5., 5., 2., 1., 1., 4., 5., 6.,
#         7., 6., 5., 2., 0., 1., 1., 0., 0., 1., 0., 0., 1.]),
#  array([40.9 , 41.47, 42.04, 42.61, 43.18, 43.75, 44.32, 44.89, 45.46,
#         46.03, 46.6 , 47.17, 47.74, 48.31, 48.88, 49.45, 50.02, 50.59,
#         51.16, 51.73, 52.3 , 52.87, 53.44, 54.01, 54.58, 55.15, 55.72,
#         56.29, 56.86, 57.43, 58.  ]),
#  <a list of 30 Patch objects>)

# %%
sns.kdeplot(df3['Body Mass (g)'])

# %%
plt.hist(df3['Culmen Depth (mm)'],bins=30)
# Out:
# (array([2., 4., 2., 0., 3., 0., 5., 2., 0., 4., 4., 2., 5., 1., 1., 5., 3.,
#         5., 1., 1., 2., 5., 1., 5., 2., 0., 1., 0., 0., 2.]),
#  array([16.4       , 16.54666667, 16.69333333, 16.84      , 16.98666667,
#         17.13333333, 17.28      , 17.42666667, 17.57333333, 17.72      ,
#         17.86666667, 18.01333333, 18.16      , 18.30666667, 18.45333333,
#         18.6       , 18.74666667, 18.89333333, 19.04      , 19.18666667,
#         19.33333333, 19.48      , 19.62666667, 19.77333333, 19.92      ,
#         20.06666667, 20.21333333, 20.36      , 20.50666667, 20.65333333,
#         20.8       ]),
#  <a list of 30 Patch objects>)

# %%
sns.kdeplot(df3['Culmen Depth (mm)'])

# %%
plt.hist(df3['Flipper Length (mm)'],bins=30)
# Out:
# (array([ 1.,  0.,  2.,  0.,  0.,  0.,  1.,  6.,  1.,  1.,  3.,  3.,  2.,
#          5.,  2., 10.,  5.,  4.,  2.,  2.,  5.,  2.,  3.,  2.,  1.,  1.,
#          0.,  0.,  3.,  1.]),
#  array([178.        , 179.13333333, 180.26666667, 181.4       ,
#         182.53333333, 183.66666667, 184.8       , 185.93333333,
#         187.06666667, 188.2       , 189.33333333, 190.46666667,
#         191.6       , 192.73333333, 193.86666667, 195.        ,
#         196.13333333, 197.26666667, 198.4       , 199.53333333,
#         200.66666667, 201.8       , 202.93333333, 204.06666667,
#         205.2       , 206.33333333, 207.46666667, 208.6       ,
#         209.73333333, 210.86666667, 212.        ]),
#  <a list of 30 Patch objects>)

# %%
plt.hist(df3['Body Mass (g)'],bins=30)
# Out:
# (array([1., 0., 1., 0., 0., 0., 0., 4., 3., 2., 6., 4., 5., 6., 5., 8., 1.,
#         6., 1., 4., 4., 0., 2., 0., 1., 2., 1., 0., 0., 1.]),
#  array([2700., 2770., 2840., 2910., 2980., 3050., 3120., 3190., 3260.,
#         3330., 3400., 3470., 3540., 3610., 3680., 3750., 3820., 3890.,
#         3960., 4030., 4100., 4170., 4240., 4310., 4380., 4450., 4520.,
#         4590., 4660., 4730., 4800.]),
#  <a list of 30 Patch objects>)

# %%
plt.scatter(df3['Delta 15 N (o/oo)'],df3['Delta 13 C (o/oo)'])
plt.xlabel('Delta 15 N (o/oo)')
plt.ylabel('Delta 13 C (o/oo)')
# Out:
# Text(0, 0.5, 'Delta 13 C (o/oo)')

# %%
sns.scatterplot(df3['Delta 15 N (o/oo)'],df3['Delta 13 C (o/oo)'],hue=df3['Island'])

# %%
sns.barplot(df3['Sex'],df3['Culmen Length (mm)'])

# %%
sns.barplot(df3['Sex'],df3['Culmen Depth (mm)'])

# %%
sns.barplot(df3['Sex'],df3['Flipper Length (mm)'])

# %%
sns.barplot(df3['Sex'],df3['Body Mass (g)'])

# %% [markdown]
# ## Analysis of features

# %%
df3.head(2)
# Out:
#   studyName  Sample Number                                    Species  Region  \
# 0   PAL0708              1  Chinstrap penguin (Pygoscelis antarctica)  Anvers
# 1   PAL0708              2  Chinstrap penguin (Pygoscelis antarctica)  Anvers
#
#   Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Dream  Adult, 1 Egg Stage         N61A1                No  2007-11-19
# 1  Dream  Adult, 1 Egg Stage         N61A2                No  2007-11-19
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                46.5               17.9                  192           3500
# 1                50.0               19.5                  196           3900
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0  FEMALE            9.03935          -24.30229
# 1    MALE            8.92069          -24.23592
#
#                                 Comments
# 0  Nest never observed with full clutch.
# ...

# %%
df3['studyName'].value_counts()
# Out:
# PAL0708    26
# PAL0910    24
# PAL0809    18
# Name: studyName, dtype: int64

# %%
df3['Species'].value_counts()
# Out:
# Chinstrap penguin (Pygoscelis antarctica)    68
# Name: Species, dtype: int64

# %%
df3['Region'].value_counts()
# Out:
# Anvers    68
# Name: Region, dtype: int64

# %%
df3['Island'].value_counts()
# Out:
# Dream    68
# Name: Island, dtype: int64

# %%
df3['Stage'].value_counts()
# Out:
# Adult, 1 Egg Stage    68
# Name: Stage, dtype: int64

# %%
df3['Individual ID'].value_counts()
# Out:
# N67A2     2
# N67A1     2
# N61A2     2
# N69A2     2
# N61A1     2
# N72A1     2
# N62A1     2
# N62A2     2
# N69A1     2
# N72A2     2
# N66A2     1
# N94A1     1
# N88A2     1
# N93A1     1
# N96A2     1
# N98A2     1
# N95A2     1
# N70A1     1
# N94A2     1
# N90A1     1
# N63A1     1
# N93A2     1
# N73A1     1
# N86A1     1
# N96A1     1
# N88A1     1
# N100A2    1
# N63A2     1
# N71A2     1
# N90A2     1
# N70A2     1
# N75A2     1
# N86A2     1
# N87A1     1
# N65A1     1
# N89A1     1
# N100A1    1
# N68A1     1
# N85A2     1
# N66A1     1
# N74A2     1
# N71A1     1
# N99A1     1
# N64A2     1
# N68A2     1
# N92A2     1
# N75A1     1
# N65A2     1
# N95A1     1
# N89A2     1
# N74A1     1
# N87A2     1
# N85A1     1
# N98A1     1
# N73A2     1
# N64A1     1
# N92A1     1
# N99A2     1
# Name: Individual ID, dtype: int64

# %%
df3['Clutch Completion'].value_counts()
# Out:
# Yes    54
# No     14
# Name: Clutch Completion, dtype: int64

# %%
df3['Sex'].value_counts()
# Out:
# MALE      34
# FEMALE    34
# Name: Sex, dtype: int64

# %% [markdown]
# ## Inference from analysis of the dataset

# %% [raw]
# This is the exploratory data analysis of the dataset containing the features of the species, Chinstrap penguin (Pygoscelis antarctica). General statistics are as follows:
#
# Culmen Length (mm)   : Around 46-52
# Culmen Depth (mm)    : Around 17.5-19.5
# Flipper Length (mm)  : Around 195-200
# Body Mass (g)        : Around 3500-4000
#
# All the species reside in the Dream island in the Anvers region.
# It is also observed that the male species in general have more Culmen Length, Culmen Depth, FlipperLength and Body Mass than the female species.
# There is no particular relation in the values of Delta 15 N (o/oo) and Delta 13 C (o/oo) values and seems to be uniformly distributed.They state the information about the presence of Nitrogen15 and Carbon13 isotopes.
